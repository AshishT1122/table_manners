# %%
def f(n):
    with open('enwiki-latest-pages-articles.xml', 'r') as file:
        for _ in range(n):
            try:
                line = file.readline()
                print(line)
            except UnicodeDecodeError:
                continue
            
f(1000)
